# %% [raw]
# ---
# description: Utility functions
# output-file: utils.html
# title: Utilities
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(execute)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/utils.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### execute
#
# >      execute (obj, **kwargs)
#
# Call the exec method of `obj` if it exists, otherwise return the string representation of `obj`

# %%
#| echo: false
#| output: asis
show_doc(to_sql)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/utils.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### to_sql
#
# >      to_sql (l)

# %%
#| echo: false
#| output: asis
show_doc(quote_symbol)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/utils.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### quote_symbol
#
# >      quote_symbol (quote)
#
# generate quote symbol to use for tables and columns

# %%
l = [23, 42]
test_eq(to_sql(l), '(23, 42)')
l = ['category1', 'category2']
test_eq(to_sql(l), "('category1', 'category2')")

# %%
#| echo: false
#| output: asis
show_doc(delegates)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/utils.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### delegates
#
# >      delegates (to)
#
# Decorator: replace func name, signature and docstring with `to`'s.
