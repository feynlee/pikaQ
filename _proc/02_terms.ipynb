# %% [raw]
# ---
# description: Relevant small pieces in a SQL query.
# output-file: terms.html
# title: Terms
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Value

# %%
#| echo: false
#| output: asis
show_doc(NullValue)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### NullValue
#
# >      NullValue ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Value)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L23){target="_blank" style="float:right; font-size:smaller"}
#
# ### Value
#
# >      Value (value)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Term)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L14){target="_blank" style="float:right; font-size:smaller"}
#
# ### Term
#
# >      Term ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
test_eq(Value(2).get_sql(), '2')
test_eq(Value('abc').get_sql(), "'abc'")
test_eq(Value(2).as_('col1').get_sql(), '2 as col1')
test_eq(Value('abc').as_('col1').get_sql(), "'abc' as col1")
test_eq(Value([1,2,3]).get_sql(), '(1, 2, 3)')
test_eq(Value(['col1', 'col2', 'col3']).get_sql(), "('col1', 'col2', 'col3')")
test_eq(NullValue().get_sql(), 'NULL')
test_eq(NullValue().as_('col1').get_sql(), 'NULL as col1')
test_eq(Value(Value(2)).get_sql(), '2')

# %% [markdown]
# ## Field

# %%
#| echo: false
#| output: asis
show_doc(Criteria)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L225){target="_blank" style="float:right; font-size:smaller"}
#
# ### Criteria
#
# >      Criteria (this, op, other)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(ArithmeticExpression)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L151){target="_blank" style="float:right; font-size:smaller"}
#
# ### ArithmeticExpression
#
# >      ArithmeticExpression (this, op, other)
#
# Collection of methods to convert to ArithmeticExpression and Criteria

# %%
#| echo: false
#| output: asis
show_doc(Field)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L127){target="_blank" style="float:right; font-size:smaller"}
#
# ### Field
#
# >      Field (name)
#
# Collection of methods to convert to ArithmeticExpression and Criteria

# %%
#| echo: false
#| output: asis
show_doc(FieldBase)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L49){target="_blank" style="float:right; font-size:smaller"}
#
# ### FieldBase
#
# >      FieldBase ()
#
# Collection of methods to convert to ArithmeticExpression and Criteria

# %%
a = Field('a')
b = Field('b')
c = Field('c')

# Test Field
test_eq(a.get_sql(), 'a')
test_eq(c.as_('c1').get_sql(), 'c AS c1')

# Test ArithmeticExpression
test_eq((c-1).as_('new_c').get_sql(), 'c1 - 1 AS new_c')
test_eq((a+1<13).get_sql(), 'a + 1 < 13')
test_eq(((a + 1)/3).get_sql(), '(a + 1) / 3')
test_eq(((a + 1)/(b - 4)).get_sql(), '(a + 1) / (b - 4)')
test_eq(((a + 1>2) & ((b-1<10) | (b>23)) ).get_sql(), 
        'a + 1 > 2 and (b - 1 < 10 or b > 23)')
test_eq((((a + 1>2) & (b-1<=10)) | (b>100)).get_sql(), '(a + 1 > 2 and b - 1 <= 10) or b > 100')

# Test Criteria
test_eq(a.eq(b).get_sql(), 'a = b')
test_eq(a.ne(b).get_sql(), 'a <> b')
test_eq(a.gt(b).get_sql(), 'a > b')
test_eq(a.ge(b).get_sql(), 'a >= b')
test_eq(a.lt(b).get_sql(), 'a < b')
test_eq(a.le(b).get_sql(), 'a <= b')
test_eq(a.like(b).get_sql(), 'a LIKE b')
test_eq(a.not_like(b).get_sql(), 'a NOT LIKE b')
test_eq(a.ilike('%what').get_sql(), "a ILIKE '%what'")
test_eq(a.not_ilike('%hh%').get_sql(), "a NOT ILIKE '%hh%'")
test_eq(a.isin([2, 3, 5]).get_sql(), 'a IN (2, 3, 5)')
test_eq(a.notin([2, 3, 5]).get_sql(), 'a NOT IN (2, 3, 5)')
test_eq(a.isnull().get_sql(), 'a IS NULL')
test_eq(a.notnull().get_sql(), 'a IS NOT NULL')

# Test negate
test_eq((a-1>1).negate().get_sql(), 'NOT (a - 1 > 1)')

# Test quoted field
d = Field('tbl.d')
test_eq(a.get_sql(quote_char='"'), '"a"')
test_eq(d.get_sql(quote_char='"'), '"tbl"."d"')
test_eq((d - 1).get_sql(quote_char='"'), '"tbl"."d" - 1')
test_eq((d - 1 > 2).get_sql(quote_char='"'), '"tbl"."d" - 1 > 2')
test_eq((d - 3).as_('new_d').get_sql(quote_char='"'), '"tbl"."d" - 3 AS "new_d"')

# %% [markdown]
# ## Custom Functions

# %%
#| echo: false
#| output: asis
show_doc(custom_func)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L304){target="_blank" style="float:right; font-size:smaller"}
#
# ### custom_func
#
# >      custom_func (func=None, window_func=False, dialect=None)
#
# return Field

# %%
#| echo: false
#| output: asis
show_doc(DelayedFunc)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L282){target="_blank" style="float:right; font-size:smaller"}
#
# ### DelayedFunc
#
# >      DelayedFunc (func, args, kwargs, window_func=True)
#
# Delay the execution of stored function until exec is run.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | func |  |  |  |
# | args |  |  |  |
# | kwargs |  |  |  |
# | window_func | bool | True | whether this function is a window function |
# | **Returns** | **None** |  |  |

# %%
#| echo: false
#| output: asis
show_doc(kwargs_func)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L273){target="_blank" style="float:right; font-size:smaller"}
#
# ### kwargs_func
#
# >      kwargs_func (func, *args, **kwargs)
#
# Allow arbitrary kwargs. Only pass those kwargs that are specified in func to func.

# %% [markdown]
# For functions that need to be parsed differently for different dialects, you can use the [`custom_func`](https://feynlee.github.io/pikaQ/terms.html#custom_func) decorator.

# %%
@custom_func
def add_months(column, num, dialect='sql'):
    if dialect=='sql':
        return f'DATE_ADD(month, {num}, {column})'
    elif dialect=='snowflake':
        return f'MONTH_ADD({column}, {num})'


test_eq((add_months("col1", 3)-2 > 2).get_sql(), 'DATE_ADD(month, 3, col1) - 2 > 2')
test_eq((add_months("col1", 3)-2 > 2).get_sql(dialect='snowflake'), 'MONTH_ADD(col1, 3) - 2 > 2')

# %% [markdown]
# You can even overwrite or extend the existing functions by using the [`custom_func`](https://feynlee.github.io/pikaQ/terms.html#custom_func) decorator with specified `dialects` keyword argument.

# %%
@custom_func(dialect='athena')
def add_months(column, num):
    return f"DATE_ADD('month', {num}, {column})"

test_eq((add_months("col1", 5)).get_sql(dialect='athena'),
        "DATE_ADD('month', 5, col1)")

# %% [markdown]
# ## Window Clause

# %%
#| echo: false
#| output: asis
show_doc(Following)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L411){target="_blank" style="float:right; font-size:smaller"}
#
# ### Following
#
# >      Following (N=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Preceding)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L399){target="_blank" style="float:right; font-size:smaller"}
#
# ### Preceding
#
# >      Preceding (N=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(OverClause)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L332){target="_blank" style="float:right; font-size:smaller"}
#
# ### OverClause
#
# >      OverClause (expression)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(DelayedFunc.over)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L431){target="_blank" style="float:right; font-size:smaller"}
#
# ### DelayedFunc.over
#
# >      DelayedFunc.over (partition_by)

# %%
#| echo: false
#| output: asis
show_doc(ArithmeticExpression.over)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L427){target="_blank" style="float:right; font-size:smaller"}
#
# ### ArithmeticExpression.over
#
# >      ArithmeticExpression.over (partition_by)

# %%
test_eq(
    OverClause('SUM(col1)').over('col0').orderby('col2').rows(Preceding(3), CURRENT_ROW).get_sql(), 
    'SUM(col1) OVER (PARTITION BY col0 ORDER BY col2 ROWS BETWEEN 3 PRECEDING AND CURRENT_ROW)')

@custom_func(window_func=True)
def LAG(column, offset=1, default=None):
    if default is None:
        return f"LAG({column}, {offset})"
    else:
        return f"LAG({column}, {offset}, {default})"

test_eq(
    LAG(Field('col2'), 1).over('col1').orderby('col3').range(Preceding(), Following(2)).get_sql(),
    'LAG(col2, 1) OVER (PARTITION BY col1 ORDER BY col3 RANGE BETWEEN UNBOUNDED PRECEDING AND 2 FOLLOWING)'
)

# %% [markdown]
# ## Case

# %%
#| echo: false
#| output: asis
show_doc(Case)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/terms.py#L439){target="_blank" style="float:right; font-size:smaller"}
#
# ### Case
#
# >      Case ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
test_eq(Case().when(Field('column1')>3, True).else_(False).get_sql(), 
        'CASE\nWHEN column1 > 3 THEN True\nELSE False\nEND')
test_eq(Case().when(Field('column1')>3, 1).when(Field('column1')<1, -1).else_(0).get_sql(), 
        'CASE\nWHEN column1 > 3 THEN 1\nWHEN column1 < 1 THEN -1\nELSE 0\nEND')
