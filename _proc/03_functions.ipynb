# %% [raw]
# ---
# description: Some commonly used SQL Functions.
# output-file: functions.html
# title: Functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# # Custom Function

# %%
#| echo: false
#| output: asis
show_doc(CustomFunction.over)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/functions.py#L57){target="_blank" style="float:right; font-size:smaller"}
#
# ### CustomFunction.over
#
# >      CustomFunction.over (partition_by)

# %%
#| echo: false
#| output: asis
show_doc(CustomFunction)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/functions.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### CustomFunction
#
# >      CustomFunction (func_name:str, arg_names:list, window_func=False,
# >                      distinct_option=False)
#
# A convenient class for creating custom functions.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | func_name | str |  | name of the function |
# | arg_names | list |  | list of arg names |
# | window_func | bool | False | whether this can be used as a window function |
# | distinct_option | bool | False | whether this function can be used with the distinct option |
# | **Returns** | **None** |  |  |

# %% [markdown]
# [`CustomFunction`](https://feynlee.github.io/pikaQ/functions.html#customfunction) is a convenient class to create a custom SQL function with the name, and positional arguments, if you don't need the function to be parsed differently for different dialects.

# %%
date_diff = CustomFunction('DATE_DIFF', ['interval', 'start_date', 'end_date'])
test_eq(date_diff('day', 'start_date', 'end_date').get_sql(), 'DATE_DIFF(day, start_date, end_date)')

# %%
date_diff = CustomFunction('DATE_DIFF', ['interval', 'start_date', 'end_date'])
test_eq(date_diff('month', Field('date1'), Field('date2')).get_sql(), 'DATE_DIFF(month, date1, date2)')

# %% [markdown]
# ## Commonly Used Functions

# %%
#| echo: false
#| output: asis
show_doc(convert_date_format)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/functions.py#L88){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_date_format
#
# >      convert_date_format (format, dialect='sql')

# %%
#| echo: false
#| output: asis
show_doc(Max, name='Max')
# Out:
# ---
#
# ### Max
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Min, name='Min')
# Out:
# ---
#
# ### Min
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Sum, name='Sum')
# Out:
# ---
#
# ### Sum
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Avg, name='Avg')
# Out:
# ---
#
# ### Avg
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Count, name='Count')
# Out:
# ---
#
# ### Count
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Abs, name='Abs')
# Out:
# ---
#
# ### Abs
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Round, name='Round')
# Out:
# ---
#
# ### Round
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(First, name='First')
# Out:
# ---
#
# ### First
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Last, name='Last')
# Out:
# ---
#
# ### Last
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Cast, name='Cast')
# Out:
# ---
#
# ### Cast
#
# >      Cast (*args, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(Coalesce, name='Coalesce')
# Out:
# ---
#
# ### Coalesce
#
# >      Coalesce (*args, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(Concat, name='Concat')
# Out:
# ---
#
# ### Concat
#
# >      Concat (*args, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(Date, name='Date')
# Out:
# ---
#
# ### Date
#
# >      Date (*args, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(AddMonths, name='AddMonths')
# Out:
# ---
#
# ### AddMonths
#
# >      AddMonths (*args, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(DateDiff, name='DateDiff')
# Out:
# ---
#
# ### DateDiff
#
# >      DateDiff (*args, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(DateTrunc, name='DateTrunc')
# Out:
# ---
#
# ### DateTrunc
#
# >      DateTrunc (*args, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(MonthsBetween, name='MonthsBetween')
# Out:
# ---
#
# ### MonthsBetween
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(RowNumber, name='RowNumber')
# Out:
# ---
#
# ### RowNumber
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Rank, name='Rank')
# Out:
# ---
#
# ### Rank
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(DenseRank, name='DenseRank')
# Out:
# ---
#
# ### DenseRank
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(PercentRank, name='PercentRank')
# Out:
# ---
#
# ### PercentRank
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(CumeDist, name='CumeDist')
# Out:
# ---
#
# ### CumeDist
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Ntile, name='Ntile')
# Out:
# ---
#
# ### Ntile
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Lag, name='Lag')
# Out:
# ---
#
# ### Lag
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(Lead, name='Lead')
# Out:
# ---
#
# ### Lead
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(FirstValue, name='FirstValue')
# Out:
# ---
#
# ### FirstValue
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(LastValue, name='LastValue')
# Out:
# ---
#
# ### LastValue
#
#
#
# A convenient class for creating custom functions.

# %%
#| echo: false
#| output: asis
show_doc(NthValue, name='NthValue')
# Out:
# ---
#
# ### NthValue
#
#
#
# A convenient class for creating custom functions.

# %%
test_eq(RowNumber().over(Field('col1')).orderby(Field('col2')).get_sql(), 'ROW_NUMBER() OVER (PARTITION BY col1 ORDER BY col2)')
test_eq(Rank().over(Field('col1')).orderby(Field('col2')).get_sql(), 
        'RANK() OVER (PARTITION BY col1 ORDER BY col2)')
test_eq(DenseRank().over(Field('col1')).orderby(Field('col2')).get_sql(),
        'DENSE_RANK() OVER (PARTITION BY col1 ORDER BY col2)')
test_eq(PercentRank().over(Field('col1')).orderby(Field('col2')).get_sql(),
        'PERCENT_RANK() OVER (PARTITION BY col1 ORDER BY col2)')
test_eq(CumeDist().over(Field('col1')).orderby(Field('col2')).get_sql(),
        'CUME_DIST() OVER (PARTITION BY col1 ORDER BY col2)')
test_eq(Ntile(5).over(Field('col1')).orderby(Field('col2')).get_sql(),
        'NTILE(5) OVER (PARTITION BY col1 ORDER BY col2)')
test_eq(Lag(Field('col1'), 1).over(Field('col2')).orderby(Field('col3')).get_sql(),
        'LAG(col1, 1) OVER (PARTITION BY col2 ORDER BY col3)')
test_eq(Lead(Field('col1'), 1).over(Field('col2')).orderby(Field('col3')).get_sql(),
        'LEAD(col1, 1) OVER (PARTITION BY col2 ORDER BY col3)')
test_eq(FirstValue(Field('col1')).over(Field('col2')).orderby(Field('col3')).get_sql(),
        'FIRST_VALUE(col1) OVER (PARTITION BY col2 ORDER BY col3)')
test_eq(LastValue(Field('col1')).over(Field('col2')).orderby(Field('col3')).get_sql(),
        'LAST_VALUE(col1) OVER (PARTITION BY col2 ORDER BY col3)')
test_eq(NthValue(Field('col1'), 2).over(Field('col2')).orderby(Field('col3')).get_sql(),
        'NTH_VALUE(col1, 2) OVER (PARTITION BY col2 ORDER BY col3)')
test_eq(Count(Field('col1')).over(Field('col2')).orderby(Field('col3')).get_sql(),
        'COUNT(col1) OVER (PARTITION BY col2 ORDER BY col3)')
test_eq(Sum(Field('col1')).over(Field('col2')).orderby(Field('col3')).get_sql(),
        'SUM(col1) OVER (PARTITION BY col2 ORDER BY col3)')
test_eq(Avg(Field('col1')).over(Field('col2')).orderby(Field('col3')).get_sql(),
        'AVG(col1) OVER (PARTITION BY col2 ORDER BY col3)')
test_eq(Min(Field('col1')).over(Field('col2')).orderby(Field('col3')).get_sql(),
        'MIN(col1) OVER (PARTITION BY col2 ORDER BY col3)')
test_eq(Max(Field('col1')).over(Field('col2')).orderby(Field('col3')).get_sql(),
        'MAX(col1) OVER (PARTITION BY col2 ORDER BY col3)')

# %%
test_eq(Count(Field('col')).distinct().get_sql(), 'COUNT(DISTINCT col)')
test_eq(Sum(Field('col')).distinct().get_sql(), 'SUM(DISTINCT col)')
