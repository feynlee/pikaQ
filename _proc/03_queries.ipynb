# %% [raw]
# ---
# description: Compose the final SQL query.
# output-file: queries.html
# title: Queries
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Table

# %%
#| echo: false
#| output: asis
show_doc(Table)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/queries.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### Table
#
# >      Table (name)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
vw = Table('vw')
test_eq(vw.as_('a').get_sql(), 'vw as a')
test_eq((vw.column + 2 > 1).get_sql(), 'a.column + 2 > 1')

# %% [markdown]
# ## Query

# %%
#| echo: false
#| output: asis
show_doc(UnionQuery)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/queries.py#L188){target="_blank" style="float:right; font-size:smaller"}
#
# ### UnionQuery
#
# >      UnionQuery (q1, q2, union_type='UNION')
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(SelectQuery)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/queries.py#L77){target="_blank" style="float:right; font-size:smaller"}
#
# ### SelectQuery
#
# >      SelectQuery ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Selector)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/queries.py#L64){target="_blank" style="float:right; font-size:smaller"}
#
# ### Selector
#
# >      Selector (select_query, *args)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Joiner)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/queries.py#L51){target="_blank" style="float:right; font-size:smaller"}
#
# ### Joiner
#
# >      Joiner (select_query, query, how=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(QueryBase)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/queries.py#L47){target="_blank" style="float:right; font-size:smaller"}
#
# ### QueryBase
#
# >      QueryBase ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Query)
# Out:
# ---
#
# [source](https://github.com/feynlee/pikaQ/blob/master/pikaQ/queries.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### Query
#
# >      Query ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
q0 = (Query
      .from_(Table('tbl').as_('a'))
      .select('col1')
      .where((Field('col2')-100>2) & (Field('col3')/9<=1))
      .limit(100)
)
test_eq(q0.exec(), 
"""select col1
from tbl as a
where col2 - 100 > 2 and col3 / 9 <= 1
limit 100""")

qj = (Query
     .with_(Query.from_(Table('tbl').as_('a')).select('col1'), 's')     
     .with_(q0, 'm')
     .from_('s')
     .join('m').on('s.col1=m.col1')
     .where(Field('col1')>=10)
     .select('s.col1', 'm.col2', 'm.col3')
)
test_eq(qj.exec(), 
"""with s as (select col1
from tbl as a),
m as (select col1
from tbl as a
where col2 - 100 > 2 and col3 / 9 <= 1
limit 100)
select s.col1, m.col2, m.col3
from s
join m on s.col1=m.col1
where col1 >= 10""")

qd = (Query
     .from_('s')
     .where(Field('col1')>=10)
     .select('col1', 'col2', 'col3').distinct()
)
test_eq(qd.exec(),
"""select distinct col1, col2, col3
from s
where col1 >= 10""")
